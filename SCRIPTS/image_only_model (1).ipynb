# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import torch
import torchvision.transforms as transforms
from torchvision import models
from PIL import Image

# %%
data_path = #replace with the file path to image data
mask_path = #replace with the file path to mask data

labels_df = pd.read_csv(mask_path)
labels_df.head()
data_df = pd.read_csv(data_path)
data_df.head()

# %%
#image preprocessing
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# %%
#use ResNet to extract features
model = models.resnet18(pretrained=True)
model = torch.nn.Sequential(*list(model.children())[:-1])
model.eval()

# %%
#TASK TO COMPLETE: extract features
def extract_features(image_path):
    # 1. Load image
    # 2. Apply transform
    # 3. Pass through model
    # 4. Return flattened feature vector
    pass

# %%
#TASK TO COMPLETE: build a dataset 
features = []
labels = []

for i, row in labels_df.iterrows():
    img_path = os.path.join(data_path, row["image_name"])
    # extract features
    # feat = extract_features(img_path)
    # features.append(feat)
    # labels.append(row["label"])

# %%
#test train split 
X_train, X_test, y_train, y_test = train_test_split(
    features, labels, test_size=0.2, random_state=42
)

# %%
#TASK TO COMPLETE: train model
clf = LogisticRegression(max_iter=1000)
#fit model

# %%
#evaluate the model
y_pred = clf.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, average="macro"))
print("Recall:", recall_score(y_test, y_pred, average="macro"))
print("F1 Score:", f1_score(y_test, y_pred, average="macro"))
